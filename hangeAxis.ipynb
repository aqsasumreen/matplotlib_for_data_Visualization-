# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [3,2,4,5,1]
# 1 --> We need the exact data written in the matrix above, for which we use ticks:
# plt.xticks(x, labels=["Python", "JS", "C++", "C", "R"])
# plt.yticks(y)
# 2 --> Other than ticks, we can also set limits:
# plt.xlim(0, 8)
# plt.ylim(0, 10)
# 3 --> We can also use axis, which takes 4 values: the first 2 for x and the second 2 for y:

plt.axis([0,10, 0,7])

plt.plot(x,y)
plt.show()
