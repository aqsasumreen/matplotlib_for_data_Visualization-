# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [2,3,1,4,5]
plt.plot(x,y)
# to show text in graph
# bbox= {"facecolor": "red"} # box inside red
# plt.text(2, 4, "JAVA" , fontsize= 15,  color = "black", style = "italic", bbox= {"facecolor": "red"})
# agr hm arrows bnana chahty
plt.annotate("python", xy=(2,1), xytext=(3,3), arrowprops=dict(facecolor = "red" , shrink = 300))
plt.legend(["up"],loc="upper left")
plt.show()
